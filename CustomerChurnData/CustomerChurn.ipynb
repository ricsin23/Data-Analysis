# %% [markdown]
# # Customer Churn Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r'C:\Users\ricsi\Downloads\PROJECT--CUSTOMER-CHURN-12MAR2025095453\Capstone-project-2\Dataset\Dataset\customer_churn.csv')

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %% [markdown]
# ## Data Manipulation

# %% [markdown]
# A) Data Manipulation:
#
# a. Extract the 5th column & store it in ‘customer_5’
#
# b. Extract the 15th column & store it in ‘customer_15’
#
# c. Extract all the male senior citizens whose Payment Method is Electronic check &
# store the result in ‘senior_male_electronic’
#
# d. Extract all those customers whose tenure is greater than 70 months or their
# Monthly charges is more than 100$ & store the result in ‘customer_total_tenure’
#
# e. Extract all the customers whose Contract is of two years, payment method is Mailed
# check & the value of Churn is ‘Yes’ & store the result in ‘two_mail_yes’
#
# f. Extract 333 random records from the customer_churndataframe& store the result in
# ‘customer_333’
#
# g. Get the count of different levels from the ‘Churn’ column

# %%
customer_5 = data.iloc[:,4]
customer_5.head()
# Out:
# 0    No
# 1    No
# 2    No
# 3    No
# 4    No
# Name: Dependents, dtype: object

# %%
customer_15 = data.iloc[:,14]
customer_15
# Out:
# 0        No
# 1        No
# 2        No
# 3        No
# 4        No
#        ...
# 7038    Yes
# 7039    Yes
# 7040     No
# 7041     No
# 7042    Yes
# Name: StreamingMovies, Length: 7043, dtype: object

# %%
senior_male_electronic = data[(data['gender'] == 'Male') & (data['SeniorCitizen'] == 1) & (data['PaymentMethod'] == 'Electronic check')]

# %%
senior_male_electronic
# Out:
#       customerID gender  SeniorCitizen Partner Dependents  tenure  \
# 20    8779-QRDMV   Male              1      No         No       1
# 55    1658-BYGOY   Male              1      No         No      18
# 57    5067-XJQFU   Male              1     Yes        Yes      66
# 78    0191-ZHSKZ   Male              1      No         No      30
# 91    2424-WVHPL   Male              1      No         No       1
# ...          ...    ...            ...     ...        ...     ...
# 6837  6229-LSCKB   Male              1      No         No       6
# 6894  1400-MMYXY   Male              1     Yes         No       3
# 6914  7142-HVGBG   Male              1     Yes         No      43
# 6967  8739-WWKDU   Male              1      No         No      25
# 7032  6894-LFHLY   Male              1      No         No       1
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 20             No  No phone service             DSL             No  ...
# ...

# %%
customer_total_revenue = data[(data['tenure']>70) | (data['MonthlyCharges'] > 100)]

# %%
customer_total_revenue.head()
# Out:
#     customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 12  8091-TTVAX    Male              0     Yes         No      58          Yes
# 13  0280-XJGEX    Male              0      No         No      49          Yes
# 14  5129-JLPIS    Male              0      No         No      25          Yes
# 15  3655-SNQYZ  Female              0     Yes        Yes      69          Yes
#
#    MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 8            Yes     Fiber optic             No  ...              Yes
# 12           Yes     Fiber optic             No  ...              Yes
# 13           Yes     Fiber optic             No  ...              Yes
# 14            No     Fiber optic            Yes  ...              Yes
# 15           Yes     Fiber optic            Yes  ...              Yes
#
# ...

# %%
two_mail_yes = data[(data['Contract'] == 'Two year') & (data['PaymentMethod'] == 'Electronic check') & (data['Churn'] == 'Yes')]

# %%
two_mail_yes.head()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 336   6680-NENYN  Female              0      No         No      43
# 975   2834-JRTUA    Male              0      No         No      71
# 2003  1447-PJGGA  Female              0      No         No      57
# 2790  5013-SBUIH  Female              0      No         No      50
# 3111  8809-RIHDD    Male              0     Yes        Yes      72
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 336           Yes           Yes     Fiber optic             No  ...
# 975           Yes           Yes     Fiber optic            Yes  ...
# 2003          Yes            No     Fiber optic             No  ...
# 2790          Yes           Yes     Fiber optic            Yes  ...
# 3111          Yes           Yes     Fiber optic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 336               Yes          No         Yes             Yes  Two year
# ...

# %%
customer_333 = data.sample(n = 333)
customer_333
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1816  1663-MHLHE    Male              0      No         No       1
# 1386  8060-HIWJJ    Male              0      No         No      64
# 121   2928-HLDBA  Female              0      No         No       6
# 3886  3786-WOVKF  Female              1     Yes         No      72
# 1518  1925-GMVBW  Female              0      No         No       5
# ...          ...     ...            ...     ...        ...     ...
# 5053  4828-FAZPK  Female              0     Yes        Yes      16
# 5412  3733-UOCWF    Male              1     Yes         No      61
# 6004  6736-DHUQI  Female              0     Yes        Yes      67
# 1080  0301-KOBTQ    Male              0      No         No      32
# 3773  8260-NGFNY  Female              0      No         No       1
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 1816          Yes                No              No  No internet service  ...
# ...

# %%
churn_level_count = data['Churn'].value_counts()

# %%
churn_level_count
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# a. Build a bar-plot for the ’InternetService’ column:
#
# i. Set x-axis label to ‘Categories of Internet Service’
#
# ii. Set y-axis label to ‘Count of Categories’
#
# iii. Set the title of plot to be ‘Distribution of Internet Service’
#
# iv. Set the color of the bars to be ‘orange’

# %%
plt.bar(data['InternetService'].value_counts().keys().tolist(), data['InternetService'].value_counts().tolist(), color = 'Orange')
plt.xlabel('Categories of Internet Service')
plt.ylabel('Count of Categories')
plt.title('Distribution of Internet Service')
# Out:
# Text(0.5, 1.0, 'Distribution of Internet Service')

# %% [markdown]
# b. Build a histogram for the ‘tenure’ column:
#
# i. Set the number of bins to be 30
#
# ii. Set the color of the bins to be ‘green’
#
# iii. Assign the title ‘Distribution of tenure’

# %%
plt.hist(data['tenure'], bins = 30, color = 'green')
plt.title('Distribution of Tenure')
# Out:
# Text(0.5, 1.0, 'Distribution of Tenure')

# %% [markdown]
# c. Build a scatter-plot between ‘MonthlyCharges’ & ‘tenure’. Map ‘MonthlyCharges’ to
# the y-axis & ‘tenure’ to the ‘x-axis’:
#
# i. Assign the points a color of ‘brown’
#
# ii. Set the x-axis label to ‘Tenure of customer’
#
# iii. Set the y-axis label to ‘Monthly Charges of customer’
#
# iv. Set the title to ‘Tenure vs Monthly Charges’

# %%
plt.scatter(x = data['tenure'], y = data['MonthlyCharges'], color = "brown")
plt.xlabel('Tenure of customer')
plt.ylabel('Monthly Charges of customer')
plt.title('Tenure vs Monthly Charges')
# Out:
# Text(0.5, 1.0, 'Tenure vs Monthly Charges')

# %% [markdown]
# d. Build a box-plot between ‘tenure’ & ‘Contract’. Map ‘tenure’ on the y-axis &
# ‘Contract’ on the x-axis.

# %%
data.boxplot(column = ['tenure'], by = ['Contract'])
# Out:
# <Axes: title={'center': 'tenure'}, xlabel='[Contract]'>

# %%
## Lineae

# %% [markdown]
# a. Build a simple linear model where dependent variable is ‘MonthlyCharges’ and
# independent variable is ‘tenure’
#
# i. Divide the dataset into train and test sets in 70:30 ratio.
# ii. Build the model on train set and predict the values on test set
# iii. After predicting the values, find the root mean square error
# iv. Find out the error in prediction & store the result in ‘error’
# v. Find the root mean square error

# %%
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
y = data[['MonthlyCharges']]
x = data[['tenure']]

# %%
x.head(), y.head()
# Out:
# (   tenure
#  0       1
#  1      34
#  2       2
#  3      45
#  4       2,
#     MonthlyCharges
#  0           29.85
#  1           56.95
#  2           53.85
#  3           42.30
#  4           70.70)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.30, random_state = 0)

# %%
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((4930, 1), (4930, 1), (2113, 1), (2113, 1))

# %%
regressor = LinearRegression()

# %%
regressor.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_predictor = regressor.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
np.sqrt(mean_squared_error(y_predictor, y_test))
# Out:
# np.float64(29.394584027273893)

# %% [markdown]
# a. Build a simple logistic regression modelwhere dependent variable is ‘Churn’ &
# independent variable is ‘MonthlyCharges’
# i. Divide the dataset in 65:35 ratio
# ii. Build the model on train set and predict the values on test set
# iii. Build the confusion matrix and get the accuracy score

# %%
from sklearn.linear_model import LogisticRegression

# %%
x = data[['MonthlyCharges']]
y = data[['Churn']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.35, random_state = 0)

# %%
log_model = LogisticRegression()

# %%
log_model.fit(x_train, y_train)
# Out:
# C:\Users\ricsi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred = log_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

# %%
confusion_matrix(y_test, y_pred), accuracy_score(y_test, y_pred)
# Out:
# (array([[1815,    0],
#         [ 651,    0]]),
#  0.7360097323600974)

# %% [markdown]
# b. Build a multiple logistic regression model where dependent variable is ‘Churn’ &
# independent variables are ‘tenure’ & ‘MonthlyCharges’
# i. Divide the dataset in 80:20 ratio
# ii. Build the model on train set and predict the values on test set
# iii. Build the confusion matrix and get the accuracy score

# %%
x = data[['MonthlyCharges', 'tenure']]
y = data[['Churn']]

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.20, random_state = 0)

# %%
log_model.fit(x_train, y_train)
# Out:
# C:\Users\ricsi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\utils\validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
y_pred_2 = log_model.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_2), accuracy_score(y_test, y_pred_2)
# Out:
# (array([[934, 107],
#         [212, 156]]),
#  0.7735982966643009)

# %% [markdown]
# a. Build a decision tree model where dependent variable is ‘Churn’ & independent
# variable is ‘tenure’
# i. Divide the dataset in 80:20 ratio
# ii. Build the model on train set and predict the values on test set
# iii. Build the confusion matrix and calculate the accuracy

# %%
x = data[['tenure']]
y = data[['Churn']]

from sklearn.tree import DecisionTreeClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.20, random_state = 0)

# %%
my_tree = DecisionTreeClassifier()
my_tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_3 = my_tree.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_3), accuracy_score(y_test, y_pred_3)
# Out:
# (array([[965,  76],
#         [281,  87]]),
#  0.7466288147622427)

# %% [markdown]
# a. Build a Random Forest model where dependent variable is ‘Churn’ & independent
# variables are ‘tenure’ and ‘MonthlyCharges’
# i. Divide the dataset in 70:30 ratio
# ii. Build the model on train set and predict the values on test set
# iii. Build the confusion matrix and calculate the accuracy

# %%
x = data[['tenure']]
y = data[['Churn']]

from sklearn.ensemble import RandomForestClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30, random_state = 0)

# %%
my_forest = RandomForestClassifier()
my_forest.fit(x_train, y_train)
# Out:
# C:\Users\ricsi\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:1389: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestClassifier()

# %%
y_pred_4 = my_forest.predict(x_test)

# %%
confusion_matrix(y_test, y_pred_4), accuracy_score(y_test, y_pred_4)
# Out:
# (array([[1446,  114],
#         [ 409,  144]]),
#  0.7524846190250828)
